# %%
a = [[10, 20, 30, 40],
     [50, 60, 70, 80],
     [80, 60, 90, 40],
     [10, 20, 80, 50]]

for i in range(len(a)):
    for j in range(len(a[i])):
        print(a[i][j],end=" ")
        print()
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 80
# 60
# 90
# 40
# 10
# 20
# 80
# 50

# %%
1 2 3 4 
5 6 7 8 
8 6 9 4 
0 2 8 5
